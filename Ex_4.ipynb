# %% [markdown]
# <a href="https://colab.research.google.com/github/Purvajavenkatesh04/11239a075_OPENCV_LAB/blob/main/Ex_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/EX_4.1.png')

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %% [markdown]
# **Line on an image.**

# %%
line_img = img.copy()
cv2.line(line_img, (50, 50), (400, 50), (255, 0, 0), 3)

cv2_imshow(line_img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %% [markdown]
# **Rectangle and circle on an image**

# %%
shape_img = img.copy()

cv2.rectangle(shape_img, (50, 100), (200, 250), (0, 255, 0), 3)
cv2.circle(shape_img, (300, 200), 50, (0, 0, 255), 3)

cv2_imshow(shape_img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %% [markdown]
# **Draw multiple geometric shapes.**

# %%
multi_img = img.copy()

cv2.line(multi_img, (0, 0), (500, 500), (255, 0, 0), 2)
cv2.rectangle(multi_img, (50, 50), (150, 150), (0, 255, 0), 2)
cv2.circle(multi_img, (250, 250), 40, (0, 0, 255), -1)

cv2_imshow(multi_img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %% [markdown]
# **Write text on an image.**

# %%
text_img = img.copy()

cv2.putText(text_img, "OpenCV", (150, 300),
            cv2.FONT_HERSHEY_SIMPLEX,
            1, (0, 0, 0), 2)

cv2_imshow(text_img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %% [markdown]
# **Simple drawing canvas using OpenCV.**

# %%
canvas = img.copy()

cv2.line(canvas, (50, 50), (450, 50), (255, 0, 0), 2)
cv2.rectangle(canvas, (50, 100), (200, 250), (0, 255, 0), 2)
cv2.circle(canvas, (350, 200), 50, (0, 0, 255), 2)
cv2.putText(canvas, "Canvas", (150, 400),
            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0), 2)

cv2_imshow(canvas)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>
