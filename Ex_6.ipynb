# %% [markdown]
# <a href="https://colab.research.google.com/github/Purvajavenkatesh04/11239a075_OPENCV_LAB/blob/main/Ex_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()

import cv2
from google.colab.patches import cv2_imshow

img_path = next(iter(uploaded))

# Read in grayscale
img = cv2.imread(img_path, 0)

cv2_imshow(img)
# Out:
#      <input type="file" id="files-e3422d6e-9096-4e08-bd29-678b45ad0d4a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e3422d6e-9096-4e08-bd29-678b45ad0d4a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Apply thresholding function**

# %%
_, th1 = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
cv2_imshow(th1)
# Out:
# <PIL.Image.Image image mode=L size=389x352>

# %% [markdown]
# **Binary Threshold**

# %%
_, th2 = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY_INV)
cv2_imshow(th2)
# Out:
# <PIL.Image.Image image mode=L size=389x352>

# %% [markdown]
# **Threshold Truncate**

# %%
_, th3 = cv2.threshold(img, 127, 255, cv2.THRESH_TRUNC)
cv2_imshow(th3)
# Out:
# <PIL.Image.Image image mode=L size=389x352>

# %% [markdown]
# **Threshold to Zero**

# %%
_, th4 = cv2.threshold(img, 127, 255, cv2.THRESH_TOZERO)
cv2_imshow(th4)
# Out:
# <PIL.Image.Image image mode=L size=389x352>

# %% [markdown]
# **Adaptive Threshold**

# %%
adaptive = cv2.adaptiveThreshold(
    img, 255,
    cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
    cv2.THRESH_BINARY,
    11, 2
)

cv2_imshow(adaptive)
# Out:
# <PIL.Image.Image image mode=L size=389x352>

# %%
from google.colab import files
uploaded = files.upload()

import cv2
from google.colab.patches import cv2_imshow

img_path = next(iter(uploaded))

# read grayscale
img = cv2.imread(img_path, 0)

cv2_imshow(img)
# Out:
#      <input type="file" id="files-276ba3f8-b8c8-4414-b005-618d4f2ff5ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-276ba3f8-b8c8-4414-b005-618d4f2ff5ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
sobelx = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=5)
sobely = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=5)

cv2_imshow(sobelx)
cv2_imshow(sobely)
# Out:
# <PIL.Image.Image image mode=L size=389x352>
# <PIL.Image.Image image mode=L size=389x352>
